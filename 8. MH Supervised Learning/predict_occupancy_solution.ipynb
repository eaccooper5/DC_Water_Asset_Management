# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv("../Resources/InspectionList2.csv")
df.head()
# Out:
#    Seg_ID    UP_MH    DS_MH  Dia., Inch  Length, Ft  MWL, %  DS, % depth  \
# 0       1  36206.0  36207.0          42         200      95          0.0
# 1       2  36206.0  36207.0          60         200      95          0.0
# 2       3  36206.0  36207.0          60         200      95          0.0
# 3       4  36204.0    838.0         102         651      80          0.0
# 4       5   8197.0  36206.0          96         950      75          0.0
#
#    defects  Video Quality  Risk  Inspection Raning
# 0        1              0     1                  3
# 1        1              0     1                  3
# 2        1              0     1                  1
# 3        4              1     4                  9
# 4        1              1     1                  8

# %%
# Get the target variables. 
target = df["Risk"]
target_names = [1,2,3,4,5,6]

# %%
df.describe()
# Out:
#            Seg_ID         UP_MH         DS_MH  Dia., Inch   Length, Ft  \
# count  219.000000    219.000000    219.000000  219.000000   219.000000
# mean   110.000000   1058.079635   1045.365936   52.269406   971.493151
# std     63.364028   4981.960885   4971.212615   19.566765   930.617613
# min      1.000000      2.000000      1.600000   24.000000    11.000000
# 25%     55.500000     54.500000     52.500000   36.000000   478.500000
# 50%    110.000000     98.000000     95.000000   48.000000   601.000000
# 75%    164.500000    220.500000    218.500000   69.000000  1358.500000
# max    219.000000  36206.000000  36207.000000  102.000000  8835.000000
#
#            MWL, %  DS, % depth  Defect Bucket
# count  219.000000   219.000000     219.000000
# mean    35.251142     0.651689       2.799087
# std     14.677135     2.448967       2.162185
# min     10.000000     0.000000       1.000000
# 25%     25.000000     0.000000       2.000000
# 50%     35.000000     0.000000       2.000000
# 75%     40.000000     0.000000       3.000000
# max     95.000000    10.000000      10.000000

# %%
# Get the features. 
data = df.drop("Risk", axis=1)
feature_names = data.columns
data
# Out:
#      Seg_ID    UP_MH    DS_MH  Dia., Inch  Length, Ft  MWL, %  DS, % depth  \
# 0         1  36206.0  36207.0          42         200      95         0.00
# 1         2  36206.0  36207.0          60         200      95         0.00
# 2         3  36206.0  36207.0          60         200      95         0.00
# 3         4  36204.0    838.0         102         651      80         0.00
# 4         5   8197.0  36206.0          96         950      75         0.00
# ..      ...      ...      ...         ...         ...     ...          ...
# 214     215    401.0    400.0          39         634      40         0.00
# 215     216    404.0    403.0          54         897      25         0.04
# 216     217    400.0     31.0          54        3370      25         0.00
# 217     218    403.0    402.0          39         966      40         0.00
# 218     219    402.0    401.0          39        1010      40         0.00
#
#      defects  Video Quality  Inspection Raning
# 0          1              0                  3
# 1          1              0                  3
# 2          1              0                  1
# 3          4              1                  9
# 4          1              1                  8
# ..       ...            ...                ...
# 214        1              1                  8
# 215        1              1                  7
# 216        1              1                  7
# 217        1              1                  8
# 218        1              1                  8
#
# [219 rows x 10 columns]

# %%
# Split data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Model Accuracy
print('Test Acc: %.3f' % model.score(X_test, y_test))
# Out:
# Test Acc: 0.673

# %%
# Calculate the classification report
from sklearn.metrics import classification_report
predictions = model.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
# c:\Users\eyasu\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\eyasu\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 from sklearn.metrics import classification_report
#       3 predictions = model.predict(X_test)
# ----> 4 print(classification_report(y_test, predictions,
#       5                             target_names=target_names))
#
# File c:\Users\eyasu\anaconda3\envs\dev\lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Users\eyasu\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:2592, in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2590 else:
#    2591     longest_last_line_heading = "weighted avg"
# -> 2592     name_width = max(len(cn) for cn in target_names)
#    2593     width = max(name_width, len(longest_last_line_heading), digits)
#    2594     head_fmt = "{:>{width}s} " + " {:>9}" * len(headers)
#
# File c:\Users\eyasu\anaconda3\envs\dev\lib\site-packages\sklearn\metrics\_classification.py:2592, in <genexpr>(.0)
#    2590 else:
#    2591     longest_last_line_heading = "weighted avg"
# -> 2592     name_width = max(len(cn) for cn in target_names)
#    2593     width = max(name_width, len(longest_last_line_heading), digits)
#    2594     head_fmt = "{:>{width}s} " + " {:>9}" * len(headers)
#
# TypeError: object of type 'int' has no len()
